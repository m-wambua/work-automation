# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

# Create the webdriver instance
browser = webdriver.Chrome(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row in df.iloc[2:, 0]:
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_21700\1774182341.py:37: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[3], line 37
#      29 options.add_experimental_option("prefs", {
#      30     "download.default_directory": download_dir,
#      31     "download.prompt_for_download": False,
#      32     "download.directory_upgrade": True,
#      33     "safebrowsing.enabled": True
#      34 })
#      36 # Create the webdriver instance
# ---> 37 browser = webdriver.Chrome(executable_path=driver_path, options=options)
#      38 browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
#      39 config=configparser.ConfigParser()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chrome\webdriver.py:84, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      81     service = Service(executable_path, port, service_args, service_log_path)
#      82 service.path = DriverFinder.get_path(service, options)
# ---> 84 super().__init__(
#      85     DesiredCapabilities.CHROME["browserName"],
#      86     "goog",
#      87     port,
#      88     options,
#      89     service_args,
#      90     desired_capabilities,
#      91     service_log_path,
#      92     service,
#      93     keep_alive,
#      94 )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chromium\webdriver.py:104, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     101 self.service.start()
#     103 try:
# --> 104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#     107             browser_name=browser_name,
#     108             vendor_prefix=vendor_prefix,
#     109             keep_alive=keep_alive,
#     110             ignore_proxy=_ignore_proxy,
#     111         ),
#     112         options=options,
#     113     )
#     114 except Exception:
#     115     self.quit()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:286, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284 self._authenticator_id = None
#     285 self.start_client()
# --> 286 self.start_session(capabilities, browser_profile)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.start_session(self, capabilities, browser_profile)
#     376 w3c_caps = _make_w3c_caps(capabilities)
#     377 parameters = {"capabilities": w3c_caps}
# --> 378 response = self.execute(Command.NEW_SESSION, parameters)
#     379 if "sessionId" not in response:
#     380     response = response["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 113.0.5672.127 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00B96E73+48323]
# 	(No symbol) [0x00B29661]
# 	(No symbol) [0x00A35308]
# 	(No symbol) [0x00A5634C]
# 	(No symbol) [0x00A52093]
# 	(No symbol) [0x00A50719]
# 	(No symbol) [0x00A80DF5]
# 	(No symbol) [0x00A80ADC]
# 	(No symbol) [0x00A7A6D6]
# 	(No symbol) [0x00A5847C]
# 	(No symbol) [0x00A5957D]
# 	GetHandleVerifier [0x00DFFD5D+2575277]
# 	GetHandleVerifier [0x00E3F86E+2836158]
# 	GetHandleVerifier [0x00E396DC+2811180]
# 	GetHandleVerifier [0x00C241B0+626688]
# 	(No symbol) [0x00B3314C]
# 	(No symbol) [0x00B2F4B8]
# 	(No symbol) [0x00B2F59B]
# 	(No symbol) [0x00B221B7]
# 	BaseThreadInitThunk [0x76047D59+25]
# 	RtlInitializeExceptionChain [0x76FDB74B+107]
# 	RtlClearBits [0x76FDB6CF+191]

# %%
from cridentials import username,password

print(username,password)
# Out:
# Kiprotich.Bii Sup.Reem23!

# %%
from selenium.webdriver.chrome.service import Service

service = Service('/path/to/chromedriver')
driver = webdriver.Chrome(service=service)

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service


import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row in df.iloc[2:, 0]:
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 43
#      39 service = Service(driver_path)
#      40 #driver = webdriver.Chrome(service=service)
#      41
#      42 # Create the webdriver instance
# ---> 43 browser = webdriver.Chrome(service=service, options=options)
#      44 browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
#      45 config=configparser.ConfigParser()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chrome\webdriver.py:84, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      81     service = Service(executable_path, port, service_args, service_log_path)
#      82 service.path = DriverFinder.get_path(service, options)
# ---> 84 super().__init__(
#      85     DesiredCapabilities.CHROME["browserName"],
#      86     "goog",
#      87     port,
#      88     options,
#      89     service_args,
#      90     desired_capabilities,
#      91     service_log_path,
#      92     service,
#      93     keep_alive,
#      94 )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chromium\webdriver.py:104, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     101 self.service.start()
#     103 try:
# --> 104     super().__init__(
#     105         command_executor=ChromiumRemoteConnection(
#     106             remote_server_addr=self.service.service_url,
#     107             browser_name=browser_name,
#     108             vendor_prefix=vendor_prefix,
#     109             keep_alive=keep_alive,
#     110             ignore_proxy=_ignore_proxy,
#     111         ),
#     112         options=options,
#     113     )
#     114 except Exception:
#     115     self.quit()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:286, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     284 self._authenticator_id = None
#     285 self.start_client()
# --> 286 self.start_session(capabilities, browser_profile)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.start_session(self, capabilities, browser_profile)
#     376 w3c_caps = _make_w3c_caps(capabilities)
#     377 parameters = {"capabilities": w3c_caps}
# --> 378 response = self.execute(Command.NEW_SESSION, parameters)
#     379 if "sessionId" not in response:
#     380     response = response["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 114
# Current browser version is 113.0.5672.127 with binary path C:\Program Files\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00B96E73+48323]
# 	(No symbol) [0x00B29661]
# 	(No symbol) [0x00A35308]
# 	(No symbol) [0x00A5634C]
# 	(No symbol) [0x00A52093]
# 	(No symbol) [0x00A50719]
# 	(No symbol) [0x00A80DF5]
# 	(No symbol) [0x00A80ADC]
# 	(No symbol) [0x00A7A6D6]
# 	(No symbol) [0x00A5847C]
# 	(No symbol) [0x00A5957D]
# 	GetHandleVerifier [0x00DFFD5D+2575277]
# 	GetHandleVerifier [0x00E3F86E+2836158]
# 	GetHandleVerifier [0x00E396DC+2811180]
# 	GetHandleVerifier [0x00C241B0+626688]
# 	(No symbol) [0x00B3314C]
# 	(No symbol) [0x00B2F4B8]
# 	(No symbol) [0x00B2F59B]
# 	(No symbol) [0x00B221B7]
# 	BaseThreadInitThunk [0x76047D59+25]
# 	RtlInitializeExceptionChain [0x76FDB74B+107]
# 	RtlClearBits [0x76FDB6CF+191]

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys



import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            #load_documents='https://portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            load_documents='https://portal.epra.go.ke:8080/sonora/Case?op=g&id='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username)
            alert.send_keys(Keys.TAB)
            alert.send_keys(password)

            # Accept the alert
            alert.accept()
            time.sleep(10)


            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# Cell In[3], line 130
#     128 load_documents=f"{load_documents}{applicant_data}"
#     129 browser.get(load_documents)
# --> 130 alert.send_keys(username)
#     131 alert.send_keys(Keys.TAB)
#     132 alert.send_keys(password)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\common\alert.py:79, in Alert.send_keys(self, keysToSend)
#      73 def send_keys(self, keysToSend):
#      74     """Send Keys to the Alert.
#      75
#      76     :Args:
#      77      - keysToSend: The text to be sent to Alert.
#      78     """
# ---> 79     self.driver.execute(Command.W3C_SET_ALERT_VALUE, {"value": keys_to_typing(keysToSend), "text": keysToSend})
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=113.0.5672.129)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00728893+48451]
# 	(No symbol) [0x006BB8A1]
# 	(No symbol) [0x005C4F20]
# 	(No symbol) [0x005D8544]
# 	(No symbol) [0x0060A334]
# 	(No symbol) [0x005D824D]
# 	(No symbol) [0x0060A0B6]
# 	(No symbol) [0x005E7E08]
# 	(No symbol) [0x005E8F2D]
# 	GetHandleVerifier [0x00988E3A+2540266]
# 	GetHandleVerifier [0x009C8959+2801161]
# 	GetHandleVerifier [0x009C295C+2776588]
# 	GetHandleVerifier [0x007B2280+612144]
# 	(No symbol) [0x006C4F6C]
# 	(No symbol) [0x006C11D8]
# 	(No symbol) [0x006C12BB]
# 	(No symbol) [0x006B4857]
# 	BaseThreadInitThunk [0x75917D59+25]
# 	RtlInitializeExceptionChain [0x76F2B74B+107]
# 	RtlClearBits [0x76F2B6CF+191]

# %%
from selenium.webdriver.common.alert import Alert

# Click the button to download the documents
documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
documents_button.click()

# Wait for the authentication prompt to appear
WebDriverWait(browser, 10).until(EC.alert_is_present())

# Switch to the alert
alert = Alert(browser)

# Enter the username and password
alert.send_keys('username')
alert.send_keys(Keys.TAB)
alert.send_keys('password')

# Accept the alert
alert.accept()

# %%
driver.switch_to.alert
driver.find_element(By.ID,"userID").send_keys(username)
driver.find_element(By.ID,"password").send_keys(password)
driver.switch_to.alert.accept()
driver.switch_to.default_content()

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys



import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2, row3 in zip(df.iloc[2:, 0],df.iloc[2:,1],df.iloc[2:,4]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents='https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            
            time.sleep(10)


            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[4], line 138
#     134     files = os.listdir(download_dir)
#     136 for i, input_element in enumerate(input_elements):
#     137     # Extract the value of the current input element
# --> 138     input_value = input_element.get_attribute('value')
#     139     # Store the extracted value in the dictionary using a column name based on the index of the input element
#     140     tab_data[f'Input {i + 1}'] = input_value
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webelement.py:178, in WebElement.get_attribute(self, name)
#     176 if getAttribute_js is None:
#     177     _load_js()
# --> 178 attribute_value = self.parent.execute_script(
#     179     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     180 )
#     181 return attribute_value
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:500, in WebDriver.execute_script(self, script, *args)
#     497 converted_args = list(args)
#     498 command = Command.W3C_EXECUTE_SCRIPT
# --> 500 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x01038893+48451]
# 	(No symbol) [0x00FCB8A1]
# 	(No symbol) [0x00ED5058]
# 	(No symbol) [0x00EDE1F3]
# 	(No symbol) [0x00ED86C8]
# 	(No symbol) [0x00ED86A6]
# 	(No symbol) [0x00ED7853]
# 	(No symbol) [0x00ED9DEB]
# 	(No symbol) [0x00F2CDD9]
# 	(No symbol) [0x00F1A2BC]
# 	(No symbol) [0x00F2C482]
# 	(No symbol) [0x00F1A0B6]
# 	(No symbol) [0x00EF7E08]
# 	(No symbol) [0x00EF8F2D]
# 	GetHandleVerifier [0x01298E3A+2540266]
# 	GetHandleVerifier [0x012D8959+2801161]
# 	GetHandleVerifier [0x012D295C+2776588]
# 	GetHandleVerifier [0x010C2280+612144]
# 	(No symbol) [0x00FD4F6C]
# 	(No symbol) [0x00FD11D8]
# 	(No symbol) [0x00FD12BB]
# 	(No symbol) [0x00FC4857]
# 	BaseThreadInitThunk [0x75777D59+25]
# 	RtlInitializeExceptionChain [0x7744B74B+107]
# 	RtlClearBits [0x7744B6CF+191]

# %%
https://portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID=361447

# %%
url = f"https://{username}:{password}@portal.epra.go.ke:8080"
driver.get(url)


servername

ERC-SVRV7.erc.go.ke

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys



import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username +Keys.TAB + password)
            alert.accept()
            time.sleep(10)

            alert.dismiss()

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# Cell In[7], line 129
#     127 load_documents=f"{load_documents}{applicant_data}"
#     128 browser.get(load_documents)
# --> 129 alert.send_keys(username +Keys.TAB + password)
#     130 alert.accept()
#     131 time.sleep(10)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\common\alert.py:79, in Alert.send_keys(self, keysToSend)
#      73 def send_keys(self, keysToSend):
#      74     """Send Keys to the Alert.
#      75
#      76     :Args:
#      77      - keysToSend: The text to be sent to Alert.
#      78     """
# ---> 79     self.driver.execute(Command.W3C_SET_ALERT_VALUE, {"value": keys_to_typing(keysToSend), "text": keysToSend})
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x003CDCE3+50899]
# 	(No symbol) [0x0035E111]
# 	(No symbol) [0x00265450]
# 	(No symbol) [0x00276934]
# 	(No symbol) [0x002AB974]
# 	(No symbol) [0x0027663D]
# 	(No symbol) [0x002AB6F6]
# 	(No symbol) [0x00287708]
# 	(No symbol) [0x0028886D]
# 	GetHandleVerifier [0x00633EAE+2566302]
# 	GetHandleVerifier [0x006692B1+2784417]
# 	GetHandleVerifier [0x0066327C+2759788]
# 	GetHandleVerifier [0x00465740+672048]
# 	(No symbol) [0x00368872]
# 	(No symbol) [0x003641C8]
# 	(No symbol) [0x003642AB]
# 	(No symbol) [0x003571B7]
# 	BaseThreadInitThunk [0x76597D59+25]
# 	RtlInitializeExceptionChain [0x776EB74B+107]
# 	RtlClearBits [0x776EB6CF+191]

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver

from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys



import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            driver = webdriver.Chrome(service=service, options=options)

            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username +Keys.TAB + password)
            alert.accept()
            time.sleep(10)

            # Click the "Sign In" button in the pop-up window
            cancel_button = browser.find_element(By.XPATH, '//button[text()="Cancel"]')
            cancel_button.click()


            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# Cell In[1], line 132
#     130 load_documents=f"{load_documents}{applicant_data}"
#     131 browser.get(load_documents)
# --> 132 alert.send_keys(username +Keys.TAB + password)
#     133 alert.accept()
#     134 time.sleep(10)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\common\alert.py:79, in Alert.send_keys(self, keysToSend)
#      73 def send_keys(self, keysToSend):
#      74     """Send Keys to the Alert.
#      75
#      76     :Args:
#      77      - keysToSend: The text to be sent to Alert.
#      78     """
# ---> 79     self.driver.execute(Command.W3C_SET_ALERT_VALUE, {"value": keys_to_typing(keysToSend), "text": keysToSend})
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x003CDCE3+50899]
# 	(No symbol) [0x0035E111]
# 	(No symbol) [0x00265450]
# 	(No symbol) [0x00276934]
# 	(No symbol) [0x002AB974]
# 	(No symbol) [0x0027663D]
# 	(No symbol) [0x002AB6F6]
# 	(No symbol) [0x00287708]
# 	(No symbol) [0x0028886D]
# 	GetHandleVerifier [0x00633EAE+2566302]
# 	GetHandleVerifier [0x006692B1+2784417]
# 	GetHandleVerifier [0x0066327C+2759788]
# 	GetHandleVerifier [0x00465740+672048]
# 	(No symbol) [0x00368872]
# 	(No symbol) [0x003641C8]
# 	(No symbol) [0x003642AB]
# 	(No symbol) [0x003571B7]
# 	BaseThreadInitThunk [0x76597D59+25]
# 	RtlInitializeExceptionChain [0x776EB74B+107]
# 	RtlClearBits [0x776EB6CF+191]

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys



import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username +Keys.TAB + password)
            alert.accept()
            time.sleep(15)

            # Submit the login form
            password_element.send_keys(Keys.RETURN)

            # Switch to the new tab
            browser.switch_to.window(browser.window_handles[-1])

            # Perform the desired action on the floating widget
            # For example, click the "Cancel" button
            cancel_button = browser.find_element(By.ID, 'cancel-button')
            cancel_button.click()

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connection.py:454, in HTTPConnection.getresponse(self)
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#
# File ~\somethingempyt\lib\http\client.py:1347, in HTTPConnection.getresponse(self)
#    1346 try:
# -> 1347     response.begin()
#    1348 except ConnectionError:
#
# File ~\somethingempyt\lib\http\client.py:307, in HTTPResponse.begin(self)
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#
# File ~\somethingempyt\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#
# File ~\somethingempyt\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# Cell In[11], line 47
#      43 #driver = webdriver.Chrome(service=service)
#      44
#      45 # Create the webdriver instance
#      46 browser = webdriver.Chrome(service=service, options=options)
# ---> 47 browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
#      48 config=configparser.ConfigParser()
#      49 config.read('config.ini')
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:438, in WebDriver.execute(self, driver_command, params)
#     435     elif "sessionId" not in params:
#     436         params["sessionId"] = self.session_id
# --> 438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
#     440     self.error_handler.check_response(response)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\poolmanager.py:433, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     431     response = conn.urlopen(method, url, **kw)
#     432 else:
# --> 433     response = conn.urlopen(method, u.request_uri, **kw)
#     435 redirect_location = redirect and response.get_redirect_location()
#     436 if not redirect_location:
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841 elif isinstance(new_e, (OSError, HTTPException)):
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#     849 # Keep track of the error for the retry warning.
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\util\retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     467 elif error and self._is_read_error(error):
#     468     # Read retry?
#     469     if read is False or method is None or not self._is_method_retryable(method):
# --> 470         raise reraise(type(error), error, _stacktrace)
#     471     elif read is not None:
#     472         read -= 1
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      36 try:
#      37     if value.__traceback__ is not tb:
# ---> 38         raise value.with_traceback(tb)
#      39     raise value
#      40 finally:
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File ~\somethingempyt\lib\http\client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File ~\somethingempyt\lib\http\client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File ~\somethingempyt\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File ~\somethingempyt\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import base64
import requests


import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080'
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            session=requests.Session()
            session.auth=(username,password)
            response=session.get(load_documents)
            
    # Check the response status code
            if response.status_code == 200:

                # The request was successful, so parse the response
                parsed_response = response.json()

                # Extract the applicant data
                applicant_data = parsed_response['applicant']

                # Append the applicant data to the DataFrame
                df_data = pd.concat([df_data, pd.DataFrame(applicant_data, index=[0])], ignore_index=True)

            else:

        # The request failed, so print an error message
                print(f"Request failed with status code {response.status_code}")

            time.sleep(15)

            # Submit the login form
            
            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\util\url.py:425, in parse_url(url)
#     424 auth = auth or None
# --> 425 host, port = _HOST_PORT_RE.match(host_port).groups()  # type: ignore[union-attr]
#     426 if auth and normalize_uri:
#
# AttributeError: 'NoneType' object has no attribute 'groups'
#
# The above exception was the direct cause of the following exception:
#
# LocationParseError                        Traceback (most recent call last)
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\models.py:434, in PreparedRequest.prepare_url(self, url, params)
#     433 try:
# --> 434     scheme, auth, host, port, path, query, fragment = parse_url(url)
#     435 except LocationParseError as e:
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\urllib3\util\url.py:451, in parse_url(url)
#     450 except (ValueError, AttributeError) as e:
# --> 451     raise LocationParseError(source_url) from e
#     453 # For the sake of backwards compatibility we put empty
#     454 # string values for path if there are any defined values
#     455 # beyond the path in the URL.
#     456 # TODO: Remove this when we break backwards compatibility.
#
# LocationParseError: Failed to parse: https://Kiprotich.Bii:Sup.Reem23!@portal.epra.go.ke:8080363872
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# Cell In[7], line 131
#     129         session=requests.Session()
#     130         session.auth=(username,password)
# --> 131         response=session.get(load_documents)
#     133 # Check the response status code
#     134         if response.status_code == 200:
#     135
#     136             # The request was successful, so parse the response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\requests\models.py:436, in PreparedRequest.prepare_url(self, url, params)
#     434     scheme, auth, host, port, path, query, fragment = parse_url(url)
#     435 except LocationParseError as e:
# --> 436     raise InvalidURL(*e.args)
#     438 if not scheme:
#     439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#
# InvalidURL: Failed to parse: https://Kiprotich.Bii:Sup.Reem23!@portal.epra.go.ke:8080363872

# %%
# Improvement 1 from chatgpt on the same
'''
In this code, I have made the following changes:

Moved the applicant_data dictionary creation inside the tab loop, ensuring a new dictionary is created for each tab iteration.
Created a new tab_data dictionary to store the extracted data for the current tab.
Appended tab_data to the df_data DataFrame for each tab iteration.
'''
import configparser #package
from cridentials import username,password 
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import base64
import requests


import time
import pandas as pd
import os
# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080'
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            alert = browser.switch_to.alert

            # Enter the username and password

            time.sleep(5)
            alert.send_keys(username)
            alert.send_keys(Keys.TAB)
            alert.send_keys(password)

            # Accept the alert
            alert.accept()
            time.sleep(15)

            # Submit the login form
            
            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# Cell In[10], line 129
#     127 applicant_data=row1
#     128 load_documents=f"{load_documents}{applicant_data}"
# --> 129 alert = browser.switch_to.alert
#     131 # Enter the username and password
#     133 time.sleep(5)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\switch_to.py:55, in SwitchTo.alert(self)
#      47 """Switches focus to an alert on the page.
#      48
#      49 :Usage:
#    (...)
#      52         alert = driver.switch_to.alert
#      53 """
#      54 alert = Alert(self._driver)
# ---> 55 _ = alert.text
#      56 return alert
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\common\alert.py:59, in Alert.text(self)
#      56 @property
#      57 def text(self):
#      58     """Gets the text of the Alert."""
# ---> 59     return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x003CDCE3+50899]
# 	(No symbol) [0x0035E111]
# 	(No symbol) [0x00265450]
# 	(No symbol) [0x0025E9EF]
# 	(No symbol) [0x00276774]
# 	(No symbol) [0x002AB974]
# 	(No symbol) [0x0027663D]
# 	(No symbol) [0x002AB6F6]
# 	(No symbol) [0x00287708]
# 	(No symbol) [0x0028886D]
# 	GetHandleVerifier [0x00633EAE+2566302]
# 	GetHandleVerifier [0x006692B1+2784417]
# 	GetHandleVerifier [0x0066327C+2759788]
# 	GetHandleVerifier [0x00465740+672048]
# 	(No symbol) [0x00368872]
# 	(No symbol) [0x003641C8]
# 	(No symbol) [0x003642AB]
# 	(No symbol) [0x003571B7]
# 	BaseThreadInitThunk [0x76597D59+25]
# 	RtlInitializeExceptionChain [0x776EB74B+107]
# 	RtlClearBits [0x776EB6CF+191]

# %%
# Switch to the alert
alert = driver.switch_to.alert

# Enter the username and password
alert.send_keys('username')
alert.send_keys(Keys.TAB)
alert.send_keys('password')

# Accept the alert
alert.accept()

# %%
credentials = {'username': 'your_username', 'password': 'your_password'}

browser.get(load_documents, auth=credentials)

# %%
time.sleep(15)

# Submit the login form
password_element.send_keys(Keys.RETURN)

# Switch to the new tab
browser.switch_to.window(browser.window_handles[-1])

# Perform the desired action on the floating widget
# For example, click the "Cancel" button
cancel_button = browser.find_element(By.ID, 'cancel-button')
cancel_button.click()

# %%
# Click the "Sign In" button in the pop-up window
sign_in_button = browser.find_element(By.XPATH, '//button[text()="Sign In"]')
sign_in_button.click()

# %%
import configparser
from cridentials import username, password
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys

import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd() #path for folder

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the chromedriver executable sub folders
driver_path = os.path.join(current_dir, 'chromedriver.exe')

# Configure any desired options safety
options = Options()
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

service = Service(driver_path)
#driver = webdriver.Chrome(service=service)

# Create the webdriver instance
browser = webdriver.Chrome(service=service, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')# load the configuration file
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)

# Switch to the iframe containing the login button
iframe = browser.find_element(By.XPATH, '//iframe[@name="iframe_name"]')
browser.switch_to.frame(iframe)

# Locate and click the Sign In button in the iframe
sign_in_button = browser.find_element(By.ID, 'sign_in_button')
sign_in_button.click()

# Switch back to the default content
browser.switch_to.default_content()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

            # Enter the username and password
            load_documents = f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data = row1
            load_documents = f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username + Keys.TAB + password)
            alert.accept()
            time.sleep(10)

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 52
#      49 time.sleep(15)
#      51 # Switch to the iframe containing the login button
# ---> 52 iframe = browser.find_element(By.XPATH, '//iframe[@name="iframe_name"]')
#      53 browser.switch_to.frame(iframe)
#      55 # Locate and click the Sign In button in the iframe
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//iframe[@name="iframe_name"]"}
#   (Session info: chrome=113.0.5672.127)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x003CDCE3+50899]
# 	(No symbol) [0x0035E111]
# 	(No symbol) [0x00265588]
# 	(No symbol) [0x002908F9]
# 	(No symbol) [0x00290AFB]
# 	(No symbol) [0x002BF902]
# 	(No symbol) [0x002AB944]
# 	(No symbol) [0x002BE01C]
# 	(No symbol) [0x002AB6F6]
# 	(No symbol) [0x00287708]
# 	(No symbol) [0x0028886D]
# 	GetHandleVerifier [0x00633EAE+2566302]
# 	GetHandleVerifier [0x006692B1+2784417]
# 	GetHandleVerifier [0x0066327C+2759788]
# 	GetHandleVerifier [0x00465740+672048]
# 	(No symbol) [0x00368872]
# 	(No symbol) [0x003641C8]
# 	(No symbol) [0x003642AB]
# 	(No symbol) [0x003571B7]
# 	BaseThreadInitThunk [0x76597D59+25]
# 	RtlInitializeExceptionChain [0x776EB74B+107]
# 	RtlClearBits [0x776EB6CF+191]

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.options import Options
from msedge.selenium_tools import Edge, EdgeOptions

import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver.exe')

# Configure any desired options
from msedge.selenium_tools import EdgeOptions

options = EdgeOptions()
options.use_chromium = True
options.add_experimental_option("prefs", {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
})

# Create the webdriver instance
browser = webdriver.Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# Rest of your code...
config=configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username=config.get('Credentials', 'username')
password=config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0],df.iloc[2:,1]) :
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number =row1
            applicant_name = row2
            
            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"
            
            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

# Enter the username and password
            load_documents=f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data=row1
            load_documents=f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username +Keys.TAB + password)
            alert.accept()
            time.sleep(10)


            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_15156\998193150.py:33: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 33
#      25 options.add_experimental_option("prefs", {
#      26     "download.default_directory": download_dir,
#      27     "download.prompt_for_download": False,
#      28     "download.directory_upgrade": True,
#      29     "safebrowsing.enabled": True
#      30 })
#      32 # Create the webdriver instance
# ---> 33 browser = webdriver.Edge(executable_path=driver_path, options=options)
#      34 browser.get('https://portal.erc.go.ke:8446/site/login')
#      36 # Rest of your code...
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\edge\webdriver.py:76, in WebDriver.__init__(self, executable_path, port, options, service_args, capabilities, service_log_path, service, keep_alive, verbose)
#      73     service = Service(executable_path, port, service_args, service_log_path)
#      74 service.path = DriverFinder.get_path(service, options)
# ---> 76 super().__init__(
#      77     DesiredCapabilities.EDGE["browserName"],
#      78     "ms",
#      79     port,
#      80     options,
#      81     service_args,
#      82     capabilities,
#      83     service_log_path,
#      84     service,
#      85     keep_alive,
#      86 )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chromium\webdriver.py:94, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      91     for key, value in desired_capabilities.items():
#      92         options.set_capability(key, value)
# ---> 94 if options._ignore_local_proxy:
#      95     _ignore_proxy = options._ignore_local_proxy
#      97 if not service:
#
# AttributeError: 'Options' object has no attribute '_ignore_local_proxy'

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions, EdgeService
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import os
import configparser

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver.exe')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument(f"--user-data-dir={current_dir}/chrome-data")  # Set user data directory
options.add_argument("--disable-extensions")  # Disable extensions
options.add_argument("--start-maximized")  # Maximize window on startup
prefs = {
    "download.default_directory": download_dir,
    "download.prompt_for_download": False,
    "download.directory_upgrade": True,
    "safebrowsing.enabled": True
}
options.add_experimental_option("prefs", prefs)

# Create the webdriver instance
browser = webdriver.Edge(executable_path=driver_path, options=options)

browser.get('https://portal.erc.go.ke:8446/site/login')

# Rest of your code...

# Rest of your code...


# Rest of your code...

# Rest of your code...

# Rest of your code...


# Rest of your code...


# Rest of your code...


# Rest of your code...

# Rest of your code...


# Rest of your code...
config = configparser.ConfigParser()
config.read('config.ini')
# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')
username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)
time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            alert = Alert(browser)

            # Enter the username and password
            load_documents = f'https://{username}:{password}@portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
            applicant_data = row1
            load_documents = f"{load_documents}{applicant_data}"
            browser.get(load_documents)
            alert.send_keys(username + Keys.TAB + password)
            alert.accept()
            time.sleep(10)

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)

        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_23556\2337599373.py:36: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 36
#      33 options.add_experimental_option("prefs", prefs)
#      35 # Create the webdriver instance
# ---> 36 browser = webdriver.Edge(executable_path=driver_path, options=options)
#      38 browser.get('https://portal.erc.go.ke:8446/site/login')
#      40 # Rest of your code...
#      41
#      42 # Rest of your code...
#    (...)
#      62
#      63 # Rest of your code...
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\edge\webdriver.py:76, in WebDriver.__init__(self, executable_path, port, options, service_args, capabilities, service_log_path, service, keep_alive, verbose)
#      73     service = Service(executable_path, port, service_args, service_log_path)
#      74 service.path = DriverFinder.get_path(service, options)
# ---> 76 super().__init__(
#      77     DesiredCapabilities.EDGE["browserName"],
#      78     "ms",
#      79     port,
#      80     options,
#      81     service_args,
#      82     capabilities,
#      83     service_log_path,
#      84     service,
#      85     keep_alive,
#      86 )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\chromium\webdriver.py:94, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      91     for key, value in desired_capabilities.items():
#      92         options.set_capability(key, value)
# ---> 94 if options._ignore_local_proxy:
#      95     _ignore_proxy = options._ignore_local_proxy
#      97 if not service:
#
# AttributeError: 'Options' object has no attribute '_ignore_local_proxy'

# %%
from msedge.selenium_tools import Edge, EdgeOptions, Service

# Replace these values with the actual URL, username, and password
url = "https://example.com"
username = "your_username"
password = "your_password"

# Replace this value with the path to the Microsoft Edge driver executable
driver_path = "C:/path/to/msedgedriver.exe"

# Create an EdgeOptions instance and configure any desired options
options = EdgeOptions()
options.use_chromium = True

# Create a Service object using the path to the driver executable
service = Service(driver_path)

# Create a webdriver instance using the Edge class and passing in the Service object
driver = Edge(service=service, options=options)

# Navigate to the URL that triggers the authentication prompt
driver.get(url)

# Wait for the authentication prompt to appear
alert = Alert(driver)

# Send the username and password as key presses to the prompt
alert.send_keys(username + Keys.TAB + password)
alert.accept()
