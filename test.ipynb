# %%
import pandas as pd
import os

import regex
import numpy as np

# %%
# make a transuction app using ussd?
! pipenv install requests
# Out:
# Installing requests...
#
# Installing dependencies from Pipfile.lock (9b9b56)...
# Courtesy Notice: Pipenv found itself running within a virtual environment, so it will automatically use that environment, instead of creating its own for any project. You can set PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and create its own instead. You can set PIPENV_VERBOSITY=-1 to suppress this warning.
#
#
# [    ] Installing..
# [=   ] Installing requests..
# [==  ] Installing requests..
# [=== ] Installing requests..
# [ ===] Installing requests..
# [  ==] Installing requests..
# [   =] Installing requests..
# [    ] Installing requests..
# [   =] Installing requests..
# [  ==] Installing requests..
# [ ===] Installing requests..
# [====] Installing requests..
# [=== ] Installing requests..
# [==  ] Installing requests..
# [=   ] Installing requests..
# [    ] Installing requests..
# [=   ] Installing requests..
# [==  ] Installing requests..
# ...

# %%
from requests import session

payload = {
    'action': 'login',
    'username': 'Kiprotich.Bii',
    'password': 'Long.Twenty8!'
}
global c
with session() as c:
    c.post('https://portal.erc.go.ke:8446/site/login', data=payload)
    request = c.get('https://portal.erc.go.ke:8446/new-licence-applications')
    print(request.headers)
    print(request.text)
# Out:
# {'Cache-Control': 'no-store, no-cache, must-revalidate', 'Pragma': 'no-cache', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Encoding': 'gzip', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Vary': 'Accept-Encoding', 'Server': 'Microsoft-IIS/10.0', 'X-Powered-By': 'PHP/7.2.7, ASP.NET', 'Date': 'Fri, 28 Apr 2023 06:39:04 GMT', 'Content-Length': '2430'}
# <!DOCTYPE html>
# <html lang="en-US">
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon">
#         <link rel="icon" href="/favicon.ico" type="image/x-icon">
#         <link rel="stylesheet" href="/fullcalendar/fullcalendar.min.css" type="text/css"/>
#         <meta name="csrf-param" content="_csrf-staffportal">
#     <meta name="csrf-token" content="qm3F3xgs2kdbqAN5ERb_qK6mBtfIdKuyZcCpqGwUJ7X5IY-PfmeeISHjUjx4f4btm85LoKIc3P4mtODxB3F43w==">
# ...

# %%
from bs4 import BeautifulSoup

# Assume 'html_doc' contains the HTML content of the web page
html_doc=request.text
soup = BeautifulSoup(html_doc, 'html.parser')

# Find a specific tag with a specific attribute
tag = soup.find('div', {'class': 'my-class'})

# Extract the text content of the tag
text = tag.text

# Find all tags of a specific type
tags = soup.find_all('a')

# Loop through the tags and extract their attributes
for tag in tags:
    href = tag.get('href')
    print(href)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 11
#       8 tag = soup.find('div', {'class': 'my-class'})
#      10 # Extract the text content of the tag
# ---> 11 text = tag.text
#      13 # Find all tags of a specific type
#      14 tags = soup.find_all('a')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the URL of the web page
response = requests.get('https://portal.erc.go.ke:8446/new-licence-applications')

# Check if the request was successful
if response.status_code == 200:
    # Get the HTML content of the web page
    html_doc = response.text

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_doc, 'html.parser')

    # Use BeautifulSoup to extract data from the HTML
    # ...
else:
    print('Failed to retrieve web page')

# %%
html_doc = response.text

    # Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

tag = soup.find('div', {'class': 'main container'})

# Extract the text content of the tag
#text = tag.text

# Find all tags of a specific type
tags = soup.find_all('a')

# Loop through the tags and extract their attributes
for tag in tags:
    href = tag.get('href')
    print(href)

# %%
soup.html.body.div
# Out:
# <div class="container" id="bana-area">
# <div class="row">
# <div class="col-lg-12">
# <img src="/assets/images/EPRA-logo.png" style="height: 75px; width: 30%;"/>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12"> </div>
# </div>
# </div>

# %%
from selenium import webdriver
driver=webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19624\3839459230.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')

# %%
from selenium import webdriver
driver=webdriver.Chrome()

driver.get('https://portal.erc.go.ke:8446/new-licence-applications/review?ref=281037')

# %%
import pandas as pd
df=pd.read_csv("C:/Users/ip 5/Downloads/data.csv")

df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

chromedriver = r'C:\Users\ip 5\mike\work_related\chromedriver.exe'
browser = webdriver.Chrome(chromedriver)
browser.get('https://portal.erc.go.ke:8446/new-licence-applications')
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19624\3306820839.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(chromedriver)

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
driver= webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
driver.get("https://portal.erc.go.ke:8446/new-licence-applications")
main_menu=driver.find_element(By.LINK_TEXT,"Electricity Department")
ActionChains(driver)\
 .move_to_element(main_menu)\
 .perform()
# Wait for sub menu to be displayed
WebDriverWait(driver, 3).until(EC.visibility_of_element_located 
((By.LINK_TEXT, "Excel")))
sub_menu=driver.find_element(By.LINK_TEXT,"Excel")
sub_menu.click()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19624\2808854107.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[29], line 8
#       6 driver= webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
#       7 driver.get("https://portal.erc.go.ke:8446/new-licence-applications")
# ----> 8 main_menu=driver.find_element(By.LINK_TEXT,"Electricity Department")
#       9 ActionChains(driver)\
#      10  .move_to_element(main_menu)\
#      11  .perform()
#      12 # Wait for sub menu to be displayed
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
driver= webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
driver.get("https://portal.erc.go.ke:8446/new-licence-applications")
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

username = browser.find_element(By.NAME,'Username')
password = browser.find_element(By.NAME,'Password')

username.send_keys("Kiprotich.Bii")
password.send_keys("Long.Twenty8!")

login_button = browser.find_element(By.NAME,'Login')
login_button.click()
driver= webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe')
driver.get("https://portal.erc.go.ke:8446/new-licence-applications")
main_menu=driver.find_element(By.LINK_TEXT,"Electricity Department")
ActionChains(driver)\
 .move_to_element(main_menu)\
 .perform()
# Wait for sub menu to be displayed
WebDriverWait(driver, 3).until(EC.visibility_of_element_located 
((By.LINK_TEXT, "Excel")))
sub_menu=driver.find_element(By.LINK_TEXT,"Excel")
sub_menu.click()
main_menu=driver.find_element(By.LINK_TEXT,"Electricity Department")
ActionChains(driver)\
 .move_to_element(main_menu)\
 .perform()
# Wait for sub menu to be displayed
WebDriverWait(driver, 3).until(EC.visibility_of_element_located 
((By.LINK_TEXT, "Excel")))
sub_menu=driver.find_element(By.LINK_TEXT,"Excel")
sub_menu.click()

# %%
from selenium import webdriver
import time

browser = webdriver.Chrome()
browser.get('https://portal.erc.go.ke:8446/site/login')

username = browser.find_element(By.NAME,'LoginForm[username]')
password = browser.find_element(By.NAME,'LoginForm[password]')

username.send_keys("Kiprotich.Bii")
password.send_keys("Long.Twenty8!")
time.sleep(10)
login_button = browser.find_element(By.NAME,'login-button')
login_button.click()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# c:\Python310\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# c:\Python310\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\Python310\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
from selenium import webdriver
import time

browser = webdriver.Chrome()
browser.get('https://portal.erc.go.ke:8446/new-licence-applications/index')

username = browser.find_element(By.NAME,'LoginForm[username]')
password = browser.find_element(By.NAME,'LoginForm[password]')

username.send_keys("Kiprotich.Bii")
password.send_keys("Long.Twenty8!")
time.sleep(10)
login_button = browser.find_element(By.NAME,'login-button')
login_button.click()

# Wait for the page to load
time.sleep(5)

# Navigate to the Electricity Department page
electricity_department = browser.find_element(By.ID,'applications-list_wrapper')
electricity_department.click()

# Wait for the sub-tab to load
time.sleep(2)

# Navigate to the License Application sub-tab
license_application = browser.find_element(By.ID,'license-application-id')
license_application.click()

# Wait for the page to load
time.sleep(2)

# Click on the Excel button to download the contents
excel_button = browser.find_element(By.ID,'excel-button-id')
excel_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[39], line 27
#      24 time.sleep(2)
#      26 # Navigate to the License Application sub-tab
# ---> 27 license_application = browser.find_element(By.ID,'license-application-id')
#      28 license_application.click()
#      30 # Wait for the page to load
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
# ...

# %%
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options


import time
options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\ip 5\mike\work_related\data",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})


browser = webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe',chrome_options=options)
browser.get('https://portal.erc.go.ke:8446/new-licence-applications/index')

username = browser.find_element(By.NAME,'LoginForm[username]')
password = browser.find_element(By.NAME,'LoginForm[password]')

username.send_keys("Kiprotich.Bii")
password.send_keys("Long.Twenty8!")
time.sleep(10)
login_button = browser.find_element(By.NAME,'login-button')
login_button.click()

# Wait for the page to load
time.sleep(5)

# Navigate to the Electricity Department page
electricity_department = browser.find_element(By.ID,'applications-list_wrapper')
electricity_department.click()

time.sleep(5)
'''
excel_button=browser.find_element(By.XPATH,"html/head/body/div[@class='row']")
excel_button.click()
'''

excel_button=browser.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(10)
import pandas as pd
#!pip install openpyxl

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
#df = df.assign(RowNumber=lambda x: range(1, len(x) + 1))

# Loop through the rows of the column containing the 'review?ref=' strings
for row in df.iloc[:,0]:
    # Split the string at the equal sign to extract the value
    value = row
    # Do something with the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row

# Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'

    browser.get(result)


    print(result)
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_6476\3100839436.py:20: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe',chrome_options=options)
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_6476\3100839436.py:20: DeprecationWarning: use options instead of chrome_options
#   browser = webdriver.Chrome(executable_path=r'C:\Users\ip 5\mike\work_related\chromedriver.exe',chrome_options=options)
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=Application No.
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=281043
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=361447
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=363872
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=368587
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=371752
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\path\to\your\code\directory",
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

driver = webdriver.Chrome(chrome_options=options)

# %%
import pandas as pd
#!pip install openpyxl

# Load the Excel file
df = pd.read_excel('C:/Users/ip 5/mike/work_related/data/ERC Internal Portal.xlsx')
#df = df.assign(RowNumber=lambda x: range(1, len(x) + 1))

# Loop through the rows of the column containing the 'review?ref=' strings
for row in df.iloc[:,0]:
    # Split the string at the equal sign to extract the value
    value = row
    # Do something with the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row

# Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    #browser.get(result)


    print(result)
# Out:
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=Application No.
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=281043
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=361447
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=363872
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=368587
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=371752
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=371845
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=371982
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=372026
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=373084
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=373439
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=373593
# https://portal.erc.go.ke:8446/new-licence-applications/review?ref=375802
# ...

# %%
'https://portal.erc.go.ke:8446/new-licence-applications/review?ref=' +
# Out:
#    ERC Internal Portal                                  Unnamed: 1  \
# 0      Application No.                                   Applicant
# 1               281043               EAST AFRICAN MALTINGS LIMITED
# 2               361447           HIGHLANDS TEA SOLAR GROUP LIMITED
# 3               363872                                 CEMTECH LTD
# 4               368587                   LEAN ENERGY SOLUTIONS LTD
# 5               371752                        CrossBoundary Energy
# 6               371845                        CrossBoundary Energy
# 7               371982                           DPA KENYA LIMITED
# 8               372026                           DPA KENYA LIMITED
# 9               373084           HIGHLANDS TEA SOLAR GROUP LIMITED
# 10              373439  Renewable Safi Power International Limited
# 11              373593                THUCHI POWER COMPANY LIMITED
# 12              375802                        CrossBoundary Energy
# ...
