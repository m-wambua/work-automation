# %%
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19052\3979357807.py:30: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 65
#      62 time.sleep(5)
#      64 # Load the Excel file
# ---> 65 df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
#      66 data = {"Links": []}
#      67 df_data = pd.DataFrame()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_openpyxl.py:549, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     539 """
#     540 Reader using openpyxl engine.
#     541
#    (...)
#     546 {storage_options}
#     547 """
#     548 import_optional_dependency("openpyxl")
# --> 549 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:530, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     526 self.handles = IOHandles(
#     527     handle=filepath_or_buffer, compression={"method": None}
#     528 )
#     529 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 530     self.handles = get_handle(
#     531         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     532     )
#     534 if isinstance(self.handles.handle, self._workbook_class):
#     535     self.book = self.handles.handle
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\ip 5\\mike\\work_related\\edge_side\\data\\ERC Internal Portal.xlsx'

# %%
# adding the click Load Button Dowuments

import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            time.sleep(5)
            # Handle the browser-level authentication prompt
            try:
                # Switch the WebDriver focus to the authentication prompt
                alert = browser.switch_to.alert

                # Pass the username and password directly to authenticate
                alert.authenticate(username, password)

                # Wait for the authentication to complete (you can adjust the sleep duration as needed)
                time.sleep(20)

                # Switch the WebDriver focus back to the main page
                browser.switch_to.default_content()

                # Continue with the rest of the code for performing actions on the authenticated page

                # ...

            except NoAlertPresentException:
                # If no authentication prompt is found, print a message or handle it accordingly
                print("No browser-level authentication prompt found.")

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)
            for file in files:
                if file.endswith('.pdf'):
                    src_path = os.path.join(download_dir, file)
                    dst_path = os.path.join(folder_path, file)
                    os.rename(src_path, dst_path)

    df_company = pd.DataFrame(data)
    df_company.to_excel("output_1.xlsx", index=False)
    df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_23772\789418577.py:32: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# No browser-level authentication prompt found.
# No browser-level authentication prompt found.
# No browser-level authentication prompt found.
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[7], line 118
#     115 os.makedirs(folder_path, exist_ok=True)
#     117 # Click the button to download the documents
# --> 118 documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
#     119 documents_button.click()
#     121 # Wait for the documents to be downloaded (adjust the wait time if needed)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a"}
#   (Session info: MicrosoftEdge=113.0.1774.57)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00E830F3+228499]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D6CB21+384465]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00BA9D1E+3950]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BD4862+93586]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BD49F0+93984]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BFA432+248162]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE83E4+174356]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCE0F3+67107]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BF8E80+242608]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE80F6+173606]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCD40B+63803]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCCBBB+61675]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCDB0D+65597]
# 	GetHandleVerifier [0x00F3D9FF+992671]
# 	Microsoft::Applications::Events::FromJSON [0x0100A4D1+132161]
# 	Microsoft::Applications::Events::FromJSON [0x01009E34+130468]
# 	Microsoft::Applications::Events::FromJSON [0x00FFFAFA+88682]
# 	Microsoft::Applications::Events::FromJSON [0x0100AEB3+134691]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D80323+464339]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75BA8+421464]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75CC3+421747]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D606D4+334212]
# 	BaseThreadInitThunk [0x76627D59+25]
# 	RtlInitializeExceptionChain [0x77BBB74B+107]
# 	RtlClearBits [0x77BBB6CF+191]

# %%
# adding the click Load Button Dowuments
# Passing the username and password in the URL itself
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            time.sleep(5)
            # Handle the browser-level authentication prompt
            try:
                # Switch the WebDriver focus to the authentication prompt
                current_url=browser.current_url
                username_password_url=f"https//{username}:{password}@{current_url.split('//')[1]}"
                browser.get(username_password_url)
                time.sleep(20)
            except NoAlertPresentException:
                # If no authentication prompt is found, print a message or handle it accordingly
                print("No browser-level authentication prompt found.")

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)
            for file in files:
                if file.endswith('.pdf'):
                    src_path = os.path.join(download_dir, file)
                    dst_path = os.path.join(folder_path, file)
                    os.rename(src_path, dst_path)

    df_company = pd.DataFrame(data)
    df_company.to_excel("output_1.xlsx", index=False)
    df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_23772\1556842297.py:32: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# Cell In[9], line 128
#     126     current_url=browser.current_url
#     127     username_password_url=f"https//{username}:{password}@{current_url.split('//')[1]}"
# --> 128     browser.get(username_password_url)
#     129     time.sleep(20)
#     130 except NoAlertPresentException:
#     131     # If no authentication prompt is found, print a message or handle it accordingly
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# InvalidArgumentException: Message: invalid argument
#   (Session info: MicrosoftEdge=113.0.1774.57)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00E830F3+228499]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D6CB21+384465]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00BA9BEA+3642]
# 	Microsoft::Applications::Events::DebugEventListener::~DebugEventListener [0x00B9DFB7+98423]
# 	Microsoft::Applications::Events::DebugEventListener::~DebugEventListener [0x00B9CB75+93237]
# 	Microsoft::Applications::Events::DebugEventListener::~DebugEventListener [0x00B9CC28+93416]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00BAB292+9442]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BF91ED+243485]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE839C+174284]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCE0F3+67107]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BF8E80+242608]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE80F6+173606]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCD40B+63803]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCCBBB+61675]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCDB0D+65597]
# 	GetHandleVerifier [0x00F3D9FF+992671]
# 	Microsoft::Applications::Events::FromJSON [0x0100A4D1+132161]
# 	Microsoft::Applications::Events::FromJSON [0x01009E34+130468]
# 	Microsoft::Applications::Events::FromJSON [0x00FFFAFA+88682]
# 	Microsoft::Applications::Events::FromJSON [0x0100AEB3+134691]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D80323+464339]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75BA8+421464]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75CC3+421747]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D606D4+334212]
# 	BaseThreadInitThunk [0x76627D59+25]
# 	RtlInitializeExceptionChain [0x77BBB74B+107]
# 	RtlClearBits [0x77BBB6CF+191]

# %%
# adding the click Load Button Dowuments
# AutoHandler
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os
import urllib.request
from urllib.error import HTTPError, URLError

# Create an instance of the AuthHandler class
auth_handler = urllib.request.HTTPBasicAuthHandler()


# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            time.sleep(5)
            # Handle the browser-level authentication prompt
            try:
                auth=(username, password)
                load_documents='https://portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
                applicant_data=row1
                load_documents=f"{load_documents}{applicant_data}"
            
                auth_handler.add_password(realm=None,uri=load_documents,user=username,passwd=password)
                opener=urllib.request.build_opener(auth_handler)
                urllib.request.install_opener(opener)
                try:
                    response=urllib.request.urlopen(load_documents)
                    html=response.read()
                    print(html)

                except HTTPError as e:
                    print(f'HTTP error {e.code}:{e.reason}')

                except URLError as e:
                    print(f'URL Error: {e.reason}')
            except NoAlertPresentException:
                # If no authentication prompt is found, print a message or handle it accordingly
                print("No browser-level authentication prompt found.")

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)
            for file in files:
                if file.endswith('.pdf'):
                    src_path = os.path.join(download_dir, file)
                    dst_path = os.path.join(folder_path, file)
                    os.rename(src_path, dst_path)

    df_company = pd.DataFrame(data)
    df_company.to_excel("output_1.xlsx", index=False)
    df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_23772\3698561167.py:38: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# HTTP error 401:Unauthorized
# HTTP error 401:Unauthorized
# HTTP error 401:Unauthorized
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 124
#     121 os.makedirs(folder_path, exist_ok=True)
#     123 # Click the button to download the documents
# --> 124 documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
#     125 documents_button.click()
#     127 # Wait for the documents to be downloaded (adjust the wait time if needed)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a"}
#   (Session info: MicrosoftEdge=113.0.1774.57)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x00E830F3+228499]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D6CB21+384465]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00BA9D1E+3950]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BD4862+93586]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BD49F0+93984]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BFA432+248162]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE83E4+174356]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCE0F3+67107]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BF8E80+242608]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BE80F6+173606]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCD40B+63803]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCCBBB+61675]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00BCDB0D+65597]
# 	GetHandleVerifier [0x00F3D9FF+992671]
# 	Microsoft::Applications::Events::FromJSON [0x0100A4D1+132161]
# 	Microsoft::Applications::Events::FromJSON [0x01009E34+130468]
# 	Microsoft::Applications::Events::FromJSON [0x00FFFAFA+88682]
# 	Microsoft::Applications::Events::FromJSON [0x0100AEB3+134691]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D80323+464339]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75BA8+421464]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D75CC3+421747]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00D606D4+334212]
# 	BaseThreadInitThunk [0x76627D59+25]
# 	RtlInitializeExceptionChain [0x77BBB74B+107]
# 	RtlClearBits [0x77BBB6CF+191]

# %%
# adding the click Load Button Dowuments
# DigestHandler
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os
import urllib.request
from urllib.error import HTTPError, URLError
from requests.auth import HTTPDigestAuth

# Create an instance of the AuthHandler class
auth_handler = urllib.request.HTTPBasicAuthHandler()


# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            time.sleep(5)
            # Handle the browser-level authentication prompt
            try:
                auth=(username, password)
                load_documents='https://portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
                applicant_data=row1
                load_documents=f"{load_documents}{applicant_data}"
            
                userrname=username
                password=password
                response=requests.get(load_documents,auth=HTTPDigestAuth(username,password),verify=False)
                if response.status_code == 200:
                    print(f"{folder_name} Downloaded Successfully")
                else:
                    print("Authentication failed. Status code:",response.status_code)
            except NoAlertPresentException:
                # If no authentication prompt is found, print a message or handle it accordingly
                print("No browser-level authentication prompt found.")

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)
            for file in files:
                if file.endswith('.pdf'):
                    src_path = os.path.join(download_dir, file)
                    dst_path = os.path.join(folder_path, file)
                    os.rename(src_path, dst_path)

    df_company = pd.DataFrame(data)
    df_company.to_excel("output_1.xlsx", index=False)
    df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_16396\1824403409.py:39: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 74
#      71 time.sleep(5)
#      73 # Load the Excel file
# ---> 74 df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
#      75 data = {"Links": []}
#      76 df_data = pd.DataFrame()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_openpyxl.py:549, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     539 """
#     540 Reader using openpyxl engine.
#     541
#    (...)
#     546 {storage_options}
#     547 """
#     548 import_optional_dependency("openpyxl")
# --> 549 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:530, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     526 self.handles = IOHandles(
#     527     handle=filepath_or_buffer, compression={"method": None}
#     528 )
#     529 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 530     self.handles = get_handle(
#     531         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     532     )
#     534 if isinstance(self.handles.handle, self._workbook_class):
#     535     self.book = self.handles.handle
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\ip 5\\mike\\work_related\\edge_side\\data\\ERC Internal Portal.xlsx'

# %%
# adding the click Load Button Dowuments
# Form based authentication
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os
import urllib.request
from urllib.error import HTTPError, URLError
from requests.auth import HTTPDigestAuth

# Create an instance of the AuthHandler class
auth_handler = urllib.request.HTTPBasicAuthHandler()


# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        # Append the extracted data for the current tab to the DataFrame
        df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

        # Check if the current tab is the "documents" tab
        if tab.text.strip() == "Documents":
            # Extract the applicant number and applicant name
            applicant_number = row1
            applicant_name = row2

            # Modify the folder name
            folder_name = f"{applicant_name.replace(' ', '_')}_{applicant_number}"

            # Create the folder if it doesn't exist
            folder_path = os.path.join(download_dir, folder_name)
            os.makedirs(folder_path, exist_ok=True)

            # Click the button to download the documents
            documents_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/h4/a')
            documents_button.click()

            # Wait for the documents to be downloaded (adjust the wait time if needed)
            time.sleep(5)
            # Handle the browser-level authentication prompt
            try:
                auth=(username, password)
                load_documents='https://portal.epra.go.ke:8080/sonora/Query?op=m&name=Electrician_LicenseFINDCASEFOLDER&width=400&height=300&APPLICATIONID='
                applicant_data=row1
                load_documents=f"{load_documents}{applicant_data}"
            
                userrname=username
                password=password
                login_data={'username': username,'password':password}
                response=requests.post(load_documents,data=login_data)
                session=requests.Session()
                if response.status_code == 200:
                    print(f"{folder_name} Downloaded Successfully")
                    response=session.get(load_documents)
                else:
                    print("Authentication failed. Status code:",response.status_code)
            except NoAlertPresentException:
                # If no authentication prompt is found, print a message or handle it accordingly
                print("No browser-level authentication prompt found.")

            # Move the downloaded documents to the applicant's folder
            files = os.listdir(download_dir)
            for file in files:
                if file.endswith('.pdf'):
                    src_path = os.path.join(download_dir, file)
                    dst_path = os.path.join(folder_path, file)
                    os.rename(src_path, dst_path)

    df_company = pd.DataFrame(data)
    df_company.to_excel("output_1.xlsx", index=False)
    df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_16396\95578334.py:39: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 74
#      71 time.sleep(5)
#      73 # Load the Excel file
# ---> 74 df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
#      75 data = {"Links": []}
#      76 df_data = pd.DataFrame()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_openpyxl.py:549, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     539 """
#     540 Reader using openpyxl engine.
#     541
#    (...)
#     546 {storage_options}
#     547 """
#     548 import_optional_dependency("openpyxl")
# --> 549 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:530, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     526 self.handles = IOHandles(
#     527     handle=filepath_or_buffer, compression={"method": None}
#     528 )
#     529 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 530     self.handles = get_handle(
#     531         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     532     )
#     534 if isinstance(self.handles.handle, self._workbook_class):
#     535     self.book = self.handles.handle
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\ip 5\\mike\\work_related\\edge_side\\data\\ERC Internal Portal.xlsx'

# %%
# Simulate Ctrl+S keystrokes
webdriver.ActionChains(driver).key_down(Keys.CONTROL).send_keys('s').key_up(Keys.CONTROL).perform()

# %%
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19052\1483624646.py:30: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 90
#      87 root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
#      89 # Check if the tab contains a table
# ---> 90 table_element = browser.find_element(By.XPATH, f'{root_xpath}//table')
#      91 if table_element:
#      92     # Extract data from the table
#      93     table_data = []
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:831, in WebDriver.find_element(self, by, value)
#     828     by = By.CSS_SELECTOR
#     829     value = f'[name="{value}"]'
# --> 831 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form//table"}
#   (Session info: MicrosoftEdge=113.0.1774.57)
# Stacktrace:
# Backtrace:
# 	GetHandleVerifier [0x007430F3+228499]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x0062CB21+384465]
# 	Microsoft::Applications::Events::ILogConfiguration::operator* [0x00469D1E+3950]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x00494862+93586]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004949F0+93984]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004BA432+248162]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004A83E4+174356]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0048E0F3+67107]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004B8E80+242608]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x004A80F6+173606]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0048D40B+63803]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0048CBBB+61675]
# 	Microsoft::Applications::Events::GUID_t::GUID_t [0x0048DB0D+65597]
# 	GetHandleVerifier [0x007FD9FF+992671]
# 	Microsoft::Applications::Events::FromJSON [0x008CA4D1+132161]
# 	Microsoft::Applications::Events::FromJSON [0x008C9E34+130468]
# 	Microsoft::Applications::Events::FromJSON [0x008BFAFA+88682]
# 	Microsoft::Applications::Events::FromJSON [0x008CAEB3+134691]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00640323+464339]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00635BA8+421464]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00635CC3+421747]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x006206D4+334212]
# 	BaseThreadInitThunk [0x758D7D59+25]
# 	RtlInitializeExceptionChain [0x7720B74B+107]
# 	RtlClearBits [0x7720B6CF+191]

# %%
# a list of xpaths
/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[4]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[6]/div/div

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[8]/form/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[10]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[10]/div/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[12]/div/div

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[16]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[18]/table


# A list of xpaths
/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[5]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[6]/form

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[8]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[10]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[16]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[18]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[20]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[22]/div[1]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[24]/div/form

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[26]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[28]/table

# %%
# A list of xpaths
/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[5]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[6]/form

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[8]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[10]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[14]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[16]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[18]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[20]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[22]/div[1]

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[24]/div/form

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[26]/table

/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[28]/table

# %%
import configparser
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from msedge.selenium_tools import Edge, EdgeOptions
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoAlertPresentException
import time
import pandas as pd
import os

# Get the current directory
current_dir = os.getcwd()

# Construct the relative path to the download directory
download_dir = os.path.join(current_dir, 'data')

# Construct the relative path to the msedgedriver executable
driver_path = os.path.join(current_dir, 'msedgedriver')

# Configure any desired options
options = EdgeOptions()
options.use_chromium = True
options.add_argument("disable-gpu")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36")

# Create the webdriver instance
browser = Edge(executable_path=driver_path, options=options)
browser.get('https://portal.erc.go.ke:8446/site/login')

# load the configuration file
config = configparser.ConfigParser()
config.read('config.ini')

# Retrieve the username and password from the configuration file
username = config.get('Credentials', 'username')
password = config.get('Credentials', 'password')

username_element = browser.find_element(By.NAME, 'LoginForm[username]')
password_element = browser.find_element(By.NAME, 'LoginForm[password]')

username_element.send_keys(username)
password_element.send_keys(password)

time.sleep(15)
login_button = browser.find_element(By.NAME, 'login-button')
login_button.click()

# Navigating to the electricity department menu
time.sleep(10)
actions = ActionChains(browser)
main_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]')
actions.move_to_element(main_menu).perform()
sub_menu = browser.find_element(By.XPATH, '/html/body/div[2]/header/nav/div/div/div[2]/ul/li[7]/ul/li[1]')
sub_menu.click()

# Clicking the Excel Button
excel_button = browser.find_element(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[1]/button[1]')
excel_button.click()
time.sleep(5)

# Load the Excel file
df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
data = {"Links": []}
df_data = pd.DataFrame()

# Loop through the rows of the column containing the 'review?ref=' strings
for row1, row2 in zip(df.iloc[2:, 0], df.iloc[2:, 1]):
    # Split the string at the equal sign to extract the value
    my_string = 'https://portal.erc.go.ke:8446/new-licence-applications/review?ref='
    my_integer = row1

    # Use an f-string to insert the integer into the string
    result = f'{my_string}{my_integer}'
    data["Links"].append(result)
    browser.get(result)
    tabs = browser.find_elements(By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div[2]/div/ul/li')
    applicant_data = {}

    for tab in tabs:
        tab.click()
        time.sleep(2)
        # Define the root XPATH
        root_xpath = '/html/body/div[2]/div/div/div[2]/div/div[2]/div/div/div[2]/div/form'
        # Locate all the input elements that are children of div elements under the root XPATH
        input_elements = browser.find_elements(By.XPATH, f'{root_xpath}//div/input')
        # Define a dictionary to store the extracted data for the current tab
        tab_data = {}

        # Loop through the located input elements
        for i, input_element in enumerate(input_elements):
            # Extract the value of the current input element
            input_value = input_element.get_attribute('value')
            # Store the extracted value in the dictionary using a column name based on the index of the input element
            tab_data[f'Input {i + 1}'] = input_value

        
        # List of tab variations
        tab_variations = [
            '',
            '/table',
            '/form',
            '/table/form',
            '/div[1]',
            '/div[2]',
            '/div[1]/table',
            '/div[2]/table',
            # Add more variations here as needed
        ]

        for tab_variation in tab_variations:
            # Generate the complete tab XPath
            tab_xpath = f'{root_xpath}/div{tab_variation}'

            # Click the tab
            tab_element = browser.find_element(By.XPATH, tab_xpath)
            tab_element.click()
            time.sleep(2)

            # Rest of your code to extract data from the tab and append it to the DataFrame
            tab_data = {}

        # Loop through the located input elements
            for i, input_element in enumerate(input_elements):
                # Extract the value of the current input element
                input_value = input_element.get_attribute('value')
                # Store the extracted value in the dictionary using a column name based on the index of the input element
                tab_data[f'Input {i + 1}'] = input_value

            # Append the extracted data for the current tab to the DataFrame
    df_data = pd.concat([df_data, pd.DataFrame(tab_data, index=[0])], ignore_index=True)

df_company = pd.DataFrame(data)
df_company.to_excel("output_1.xlsx", index=False)
df_data.to_excel('input_values.xlsx', index=False)

browser.quit()
# Out:
# C:\Users\ip 5\AppData\Local\Temp\ipykernel_19052\1058283539.py:30: DeprecationWarning: Selenium Tools for Microsoft Edge is deprecated. Please upgrade to Selenium 4 which has built-in support for Microsoft Edge (Chromium): https://docs.microsoft.com/en-us/microsoft-edge/webdriver-chromium/#upgrading-from-selenium-3
#   browser = Edge(executable_path=driver_path, options=options)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 65
#      62 time.sleep(5)
#      64 # Load the Excel file
# ---> 65 df = pd.read_excel(os.path.join(download_dir, 'ERC Internal Portal.xlsx'), engine='openpyxl')
#      66 data = {"Links": []}
#      67 df_data = pd.DataFrame()
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_openpyxl.py:549, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     539 """
#     540 Reader using openpyxl engine.
#     541
#    (...)
#     546 {storage_options}
#     547 """
#     548 import_optional_dependency("openpyxl")
# --> 549 super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\excel\_base.py:530, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options)
#     526 self.handles = IOHandles(
#     527     handle=filepath_or_buffer, compression={"method": None}
#     528 )
#     529 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 530     self.handles = get_handle(
#     531         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     532     )
#     534 if isinstance(self.handles.handle, self._workbook_class):
#     535     self.book = self.handles.handle
#
# File c:\Users\ip 5\mike\work_related\work_related\lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\ip 5\\mike\\work_related\\edge_side\\data\\ERC Internal Portal.xlsx'
